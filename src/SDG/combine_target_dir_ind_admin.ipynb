# %%
import numpy  as np
import pandas as pd
import geopandas as gpd
import xarray as xr
# import pandas_profiling

import os
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
data_folder =  "/Users/lena/OneDrive - OnTheHub - The University of Oxford/University/Oxford/OX_2018_2019/stlucia/analysis/python/projects/nismod-int-hack/data/Hackathon/rv"

# %%
#incoming 
admin_sectors_path = pd.read_csv(os.path.join(
    data_folder, 'results','admin_sectors_all_%_exp.csv'))

SDG_importance = pd.read_csv(os.path.join(
        data_folder, 'data', 'SDG', 'SDG_direct_capacity.csv'), 
                             na_values=['#VALUE!', '#DIV/0!'], 
                             header = [0, 1], index_col = [0, 1]).fillna(0)

SDG_tar_dir_ind_sector = pd.read_csv(os.path.join(
        data_folder, 'data', 'SDG', 'SDG_target_dir_ind_sectors.csv'),index_col = [0, 1])

# %%
hazard_ids = ['1m_sea-level','4m_storm-surge','flashflooding','landslide_susceptibility', 'storm_flash', 'storm_flash_landslide']

administrative_path = os.path.join(
        data_folder, 'data','admin', 'stluc_administrative.shp')

#Area here refers to natural environment area 
admin_area_exp_path = os.path.join(
    data_folder, 'results', 'admin_area_exp.csv')

admin_social_exp_path = os.path.join(
    data_folder, 'results','admin_social_sector_exp.csv')

admin_econ_exp_path = os.path.join(
    data_folder, 'results','admin_econ_sector_exp.csv')

#reading in

social_admin_stagged = pd.read_csv(admin_social_exp_path, index_col ='admin_name')
econ_admin_stagged = pd.read_csv(admin_econ_exp_path, index_col ='admin_name')
admin_area_exp = pd.read_csv(admin_area_exp_path,index_col='admin_name')

administrative = gpd.read_file(administrative_path)

# %%
admin_sector = pd.concat([econ_admin_stagged,social_admin_stagged])
admin_sector
# Out:
# /Users/lena/miniconda3/envs/nismod_int/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#               1m_sea-level  4m_storm-surge  count  flashflooding  \
# admin_name
# Anse-la-Raye           0.0             0.0    NaN          100.0
# Canaries               0.0             0.0    NaN           50.0
# Castries               0.0           100.0    NaN            0.0
# Castries               0.0            23.0    NaN           23.0
# Castries               0.0            50.0    NaN           50.0
# ...                    ...             ...    ...            ...
# Vieux Fort             0.0             0.0   12.0            0.0
# ...

# %%
admin_area_exp = admin_area_exp.drop(columns =['Unnamed: 0', 'level_0', 'index','area', 'geometry'])
admin_area_exp['sector'] = 'area'
admin_sectors = pd.concat([admin_sector, admin_area_exp])
admin_sectors
# Out:
# /Users/lena/miniconda3/envs/nismod_int/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   This is separate from the ipykernel package so we can avoid doing imports until
#               1m_sea-level  4m_storm-surge  count  flashflooding  \
# admin_name
# Anse-la-Raye           0.0             0.0    NaN          100.0
# Canaries               0.0             0.0    NaN           50.0
# Castries               0.0           100.0    NaN            0.0
# Castries               0.0            23.0    NaN           23.0
# Castries               0.0            50.0    NaN           50.0
# ...                    ...             ...    ...            ...
# Gros Islet             1.0             2.0    NaN            3.0
# ...

# %%
SDG_tar_dir_ind_sector
# Out:
#              electricity  roads  airports  freight  port  water  wastewater  \
# Goal Target
# 1    1                 1      1         0        0     0      1           0
#      2                 1      0         0        0     0      0           0
#      3                 0      0         0        0     0      0           0
#      4                 2      1         0        0     0      1           1
#      5                 1      1         0        1     0      0           0
# ...                  ...    ...       ...      ...   ...    ...         ...
# 17   15                0      0         0        0     0      0           0
#      16                0      1         1        0     1      0           0
#      17                1      1         0        0     0      1           0
#      18                0      0         1        1     1      0           0
#      19                0      0         1        0     1      0           0
#
# ...
